# %%
import pandas as pd

# %%
df=pd.read_csv("iris_original.csv")

# %%
df.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                NaN               0.2
#
#   species  growth of plant
# 0  setosa              NaN
# 1  setosa              NaN
# 2  setosa              NaN
# 3  setosa              NaN
# 4  setosa              NaN

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'species', 'growth of plant'],
#       dtype='object')

# %%
df.rename(columns = {"sepal length(cm)":"sepal_len"},inplace=True)

# %%
df.head(10)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                NaN               0.2
# 5                NaN               3.9                1.7               0.4
# 6                4.6               3.4                1.4               0.3
# 7                5.0               3.4                1.5               0.2
# 8                4.4               2.9                1.4               0.2
# 9                4.9               3.1                1.5               0.1
#
#   species  growth of plant
# 0  setosa              NaN
# 1  setosa              NaN
# 2  setosa              NaN
# ...

# %%
df.rename(columns = {"sepal length (cm)":"sepal_len"},inplace=True)

# %%
df.head(5)
# Out:
#    sepal_len  sepal width (cm)  petal length (cm)  petal width (cm) species  \
# 0        5.1               3.5                1.4               0.2  setosa
# 1        4.9               3.0                1.4               0.2  setosa
# 2        4.7               3.2                1.3               0.2  setosa
# 3        4.6               3.1                1.5               0.2  setosa
# 4        5.0               3.6                NaN               0.2  setosa
#
#    growth of plant
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal_len          148 non-null    float64
#  1   sepal width (cm)   146 non-null    float64
#  2   petal length (cm)  144 non-null    float64
#  3   petal width (cm)   147 non-null    float64
#  4   species            147 non-null    object
#  5   growth of plant    0 non-null      float64
# dtypes: float64(5), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#         sepal_len  sepal width (cm)  petal length (cm)  petal width (cm)  \
# count  148.000000        146.000000         144.000000        147.000000
# mean     5.839865          3.056849           3.833333          1.220408
# std      0.829125          0.441613           1.743720          0.755341
# min      4.300000          2.000000           1.000000          0.100000
# 25%      5.100000          2.800000           1.600000          0.300000
# 50%      5.800000          3.000000           4.400000          1.300000
# 75%      6.400000          3.375000           5.100000          1.800000
# max      7.900000          4.400000           6.900000          2.500000
#
#        growth of plant
# count              0.0
# mean               NaN
# std                NaN
# min                NaN
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max                NaN

# %%
df.shape
# Out:
# (150, 6)

# %%
df.isnull().sum()
# Out:
# sepal_len              2
# sepal width (cm)       4
# petal length (cm)      6
# petal width (cm)       3
# species                3
# growth of plant      150
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df['petal length (cm)'] = df['petal length (cm)'].fillna(df['petal length (cm)'].mean())

# %%
df.head(50)
# Out:
#     sepal_len  sepal width (cm)  petal length (cm)  petal width (cm) species  \
# 0         5.1               3.5           1.400000               0.2  setosa
# 1         4.9               3.0           1.400000               0.2  setosa
# 2         4.7               3.2           1.300000               0.2  setosa
# 3         4.6               3.1           1.500000               0.2  setosa
# 4         5.0               3.6           3.833333               0.2  setosa
# 5         NaN               3.9           1.700000               0.4  setosa
# 6         4.6               3.4           1.400000               0.3  setosa
# 7         5.0               3.4           1.500000               0.2  setosa
# 8         4.4               2.9           1.400000               0.2  setosa
# 9         4.9               3.1           1.500000               0.1  setosa
# 10        5.4               3.7           1.500000               0.2  setosa
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.columns = df.columns.str.strip()

# %%
df.dropna(axis=1, how='all', inplace=True)

# %%
df.head(10)
# Out:
#    sepal_len  sepal width (cm)  petal length (cm)  petal width (cm) species
# 0        5.1               3.5           1.400000               0.2  setosa
# 1        4.9               3.0           1.400000               0.2  setosa
# 2        4.7               3.2           1.300000               0.2  setosa
# 3        4.6               3.1           1.500000               0.2  setosa
# 4        5.0               3.6           3.833333               0.2  setosa
# 5        NaN               3.9           1.700000               0.4  setosa
# 6        4.6               3.4           1.400000               0.3  setosa
# 7        5.0               3.4           1.500000               0.2  setosa
# 8        4.4               2.9           1.400000               0.2  setosa
# 9        4.9               3.1           1.500000               0.1  setosa

# %%
df.to_csv('cleaned_file.csv', index=False)

# %%
df['sepal_len'] = df['sepal_len'].fillna(df['sepal_len'].mode()[0])

# %%
df['sepal_len'] = df['sepal_len'].fillna(df['sepal_len'].mode()[0])

# %%
df['sepal width (cm)'] = df['sepal width (cm)'].fillna(df['sepal width (cm)'].mode()[0])

# %%
df['petal width (cm)'] = df['petal width (cm)'].fillna(df['petal width (cm)'].mode()[0])

# %%
df.to_csv('cleaned_file.csv', index=False)

# %%
df['species'] = df['species'].fillna('Unknown')

# %%
df.to_csv('cleaned_file.csv', index=False)

# %%
df.head()
# Out:
#    sepal_len  sepal width (cm)  petal length (cm)  petal width (cm) species
# 0        5.1               3.5           1.400000               0.2  setosa
# 1        4.9               3.0           1.400000               0.2  setosa
# 2        4.7               3.2           1.300000               0.2  setosa
# 3        4.6               3.1           1.500000               0.2  setosa
# 4        5.0               3.6           3.833333               0.2  setosa
