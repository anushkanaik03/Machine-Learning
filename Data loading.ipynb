# %%
import pandas as pd
df=pd.read_csv('Iris.csv')

# %%
df
# Out:
#      #NAME?   Id  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0       1.0  5.1           3.5            1.4           0.2     Iris-setosa
# 1       1.0  4.9           3.0            1.4           0.2     Iris-setosa
# 2       1.0  4.9           3.2            1.3           0.2     Iris-setosa
# 3       1.0  4.9           3.1            1.5           0.2     Iris-setosa
# 4       1.0  4.9           3.6            1.4           0.2     Iris-setosa
# ..      ...  ...           ...            ...           ...             ...
# 146   147.0  6.3           2.5            5.0           1.9  Iris-virginica
# 147   148.0  6.5           3.0            5.2           2.0  Iris-virginica
# 148   149.0  6.2           3.4            5.4           2.3  Iris-virginica
# 149   150.0  5.9           3.0            5.1           1.8  Iris-virginica
# 150     NaN  NaN           5.0            6.7           3.4             NaN
#
# [151 rows x 6 columns]

# %%
df.head()
# Out:
#    #NAME?   Id  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0     1.0  5.1           3.5            1.4           0.2  Iris-setosa
# 1     1.0  4.9           3.0            1.4           0.2  Iris-setosa
# 2     1.0  4.9           3.2            1.3           0.2  Iris-setosa
# 3     1.0  4.9           3.1            1.5           0.2  Iris-setosa
# 4     1.0  4.9           3.6            1.4           0.2  Iris-setosa

# %%
df.head(7)
# Out:
#    #NAME?   Id  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0     1.0  5.1           3.5            1.4           0.2  Iris-setosa
# 1     1.0  4.9           3.0            1.4           0.2  Iris-setosa
# 2     1.0  4.9           3.2            1.3           0.2  Iris-setosa
# 3     1.0  4.9           3.1            1.5           0.2  Iris-setosa
# 4     1.0  4.9           3.6            1.4           0.2  Iris-setosa
# 5     1.0  4.9           3.9            1.7           0.4  Iris-setosa
# 6     1.0  4.9           3.4            1.4           0.3  Iris-setosa

# %%
df.isna()
# Out:
#      #NAME?     Id  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0     False  False         False          False         False    False
# 1     False  False         False          False         False    False
# 2     False  False         False          False         False    False
# 3     False  False         False          False         False    False
# 4     False  False         False          False         False    False
# ..      ...    ...           ...            ...           ...      ...
# 146   False  False         False          False         False    False
# 147   False  False         False          False         False    False
# 148   False  False         False          False         False    False
# 149   False  False         False          False         False    False
# 150    True   True         False          False         False     True
#
# [151 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# #NAME?           1
# Id               3
# SepalWidthCm     6
# PetalLengthCm    2
# PetalWidthCm     3
# Species          2
# dtype: int64

# %%
#See how many Id column are null
df[df['Id'].isna()]
# Out:
#      #NAME?  Id  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 10      1.0 NaN           NaN            NaN           NaN          NaN
# 26     27.0 NaN           3.4            1.6           0.4  Iris-setosa
# 150     NaN NaN           5.0            6.7           3.4          NaN

# %%
#See how many Species column are null
df[df['Species'].isna()]
# Out:
#      #NAME?  Id  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 10      1.0 NaN           NaN            NaN           NaN     NaN
# 150     NaN NaN           5.0            6.7           3.4     NaN

# %%
df.describe()
# Out:
#            #NAME?          Id  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000  148.000000    145.000000     149.000000    148.000000
# mean    75.060000    5.853378      3.044138       3.810738      1.232432
# std     44.157775    0.826386      0.448280       1.763869      0.777333
# min      1.000000    4.300000      2.000000       1.000000      0.100000
# 25%     38.250000    5.100000      2.800000       1.600000      0.300000
# 50%     75.500000    5.800000      3.000000       4.400000      1.300000
# 75%    112.750000    6.400000      3.300000       5.100000      1.800000
# max    150.000000    7.900000      5.000000       6.900000      3.400000

# %%
df.dtypes
# Out:
# #NAME?           float64
# Id               float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.columns
# Out:
# Index(['#NAME?', 'Id', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#Histogram
df.hist()
# Out:
# array([[<Axes: title={'center': '#NAME?'}>,
#         <Axes: title={'center': 'Id'}>],
#        [<Axes: title={'center': 'SepalWidthCm'}>,
#         <Axes: title={'center': 'PetalLengthCm'}>],
#        [<Axes: title={'center': 'PetalWidthCm'}>, <Axes: >]], dtype=object)

# %%
#Scatter plot
df.plot.scatter(x='PetalLengthCm',y='PetalWidthCm')
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   #NAME?         150 non-null    float64
#  1   Id             148 non-null    float64
#  2   SepalWidthCm   145 non-null    float64
#  3   PetalLengthCm  149 non-null    float64
#  4   PetalWidthCm   148 non-null    float64
#  5   Species        149 non-null    object
# dtypes: float64(5), object(1)
# memory usage: 7.2+ KB

# %%
df.isna().sum()
# Out:
# #NAME?           1
# Id               3
# SepalWidthCm     6
# PetalLengthCm    2
# PetalWidthCm     3
# Species          2
# dtype: int64

# %%
# median
median_sepal = df["SepalWidthCm"].median(skipna=True)
median_sepal
# Out:
# np.float64(3.0)

# %%
# Fill missing values with median
df["SepalWidthCm"] = df["SepalWidthCm"].fillna(median_sepal).astype(int)
df
# Out:
#      #NAME?   Id  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0       1.0  5.1             3            1.4           0.2     Iris-setosa
# 1       1.0  4.9             3            1.4           0.2     Iris-setosa
# 2       1.0  4.9             3            1.3           0.2     Iris-setosa
# 3       1.0  4.9             3            1.5           0.2     Iris-setosa
# 4       1.0  4.9             3            1.4           0.2     Iris-setosa
# ..      ...  ...           ...            ...           ...             ...
# 146   147.0  6.3             2            5.0           1.9  Iris-virginica
# 147   148.0  6.5             3            5.2           2.0  Iris-virginica
# 148   149.0  6.2             3            5.4           2.3  Iris-virginica
# 149   150.0  5.9             3            5.1           1.8  Iris-virginica
# 150     NaN  NaN             5            6.7           3.4             NaN
#
# [151 rows x 6 columns]
